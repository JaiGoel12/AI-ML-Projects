# %%
import pyttsx3
import speech_recognition as sr
import webbrowser
import datetime
import pyjokes
import os
import time
import requests
import wikipedia

def sptext():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
        try:
            print("recognizing...")
            data = recognizer.recognize_google(audio)
            print(f"\nUSER : {data}")
            return data.lower()
        except sr.UnknownValueError:
            print("Not Understanding...")
            print("Speak again...")
            return sptext()

def speechtx(x):
    print(f"Bot : {x}\n")
    engine = pyttsx3.init()
    voices = engine.getProperty("voices")
    engine.setProperty("voice", voices[1].id)
    rate = engine.getProperty("rate")
    engine.setProperty("rate", 150)
    engine.say(x)
    engine.runAndWait()
    
if __name__ == "__main__":
    os.system("cls")
    speechtx("Say 'hello' to activate the software")
    if sptext() == "hello":
        speechtx("Hello sir, Good evening")
        while True:
            time.sleep(2)
            data1 = sptext()
            if "your name" in data1:
                speechtx("My name is AI Bot")
            elif "time" in data1:
                speechtx(datetime.datetime.now().strftime("%I:%M %p"))
            elif "open sachin sir profile" in data1:
                webbrowser.open("https://www.linkedin.com/in/sachingarg0612?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app")
            elif "open python wikipedia" in data1:
                webbrowser.open("https://en.wikipedia.org/wiki/Python_(programming_language")
            elif "joke" in data1:
                speechtx(pyjokes.get_joke(language="en", category="all"))
            elif "play song" in data1:
                address = "E:\\song" 
                listsong = os.listdir(address)
                print(listsong)
                os.startfile(os.path.join(address, random.choice(listsong)))
            elif "repeat" in data1:
                speechtx(sptext())
            elif "exit" in data1:
                speechtx("Thank You")
                break
            else:
                speechtx("Sorry, I didn't get that.")
                speechtx("Please try anything else.")
    else:
        speechtx("bye")
# Out:
# Bot : Say 'hello' to activate the software
#
# Listening...
# recognizing...
# Not Understanding...
# Speak again...
# Listening...
# recognizing...
# Not Understanding...
# Speak again...
# Listening...
# recognizing...
#
# USER : hello
# Bot : Hello sir, Good morning
#
# Listening...
# recognizing...
# Not Understanding...
# Speak again...
# Listening...
# recognizing...
#
# USER : time
# Bot : 06:01 PM
#
# Listening...
# recognizing...
#
# USER : open Sachin Sir profile
# Listening...
# recognizing...
# Not Understanding...
# Speak again...
# Listening...
# recognizing...
# Not Understanding...
# Speak again...
# Listening...
# recognizing...
# Not Understanding...
# Speak again...
# Listening...
# recognizing...
#
# USER : Koi dikkat
# Bot : Sorry, I didn't get that.
